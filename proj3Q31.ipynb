# %%
import pandas as pd
import numpy as np

#C:\Users\Philippe\AppData\Local\Programs\Python\Python38-32\Scripts

animals = pd.read_csv('fr_animaux.csv')
veggie = pd.read_csv('fr_vegetaux.csv') 
animals["origine"] = "animal"
veggie["origine"] = "vegetal"

animals.head()
veggie.head()

animals.columns
veggie.columns
# Out:
# Index(['Code Domaine', 'Domaine', 'Code zone', 'Zone', 'Code Élément',
#        'Élément', 'Code Produit', 'Produit', 'Code année', 'Année', 'Unité',
#        'Valeur', 'Symbole', 'Description du Symbole', 'origine'],
#       dtype='object')

# %%
aniveg = animals.append(veggie)
aniveg
# Out:
#        Code Domaine                                            Domaine  \
# 0              FBSH  Bilans Alimentaire (Ancienne méthodologie et p...
# 1              FBSH  Bilans Alimentaire (Ancienne méthodologie et p...
# 2              FBSH  Bilans Alimentaire (Ancienne méthodologie et p...
# 3              FBSH  Bilans Alimentaire (Ancienne méthodologie et p...
# 4              FBSH  Bilans Alimentaire (Ancienne méthodologie et p...
# ...             ...                                                ...
# 104866         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...
# 104867         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...
# 104868         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...
# 104869         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...
# 104870         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...
#
#         Code zone         Zone  Code Élément  \
# 0               2  Afghanistan          5511
# ...

# %%
aniveg.columns
# Out:
# Index(['Code Domaine', 'Domaine', 'Code zone', 'Zone', 'Code Élément',
#        'Élément', 'Code Produit', 'Produit', 'Code année', 'Année', 'Unité',
#        'Valeur', 'Symbole', 'Description du Symbole', 'origine'],
#       dtype='object')

# %%
animals['Élément']
# Out:
# 0                                               Production
# 1                                  Importations - Quantité
# 2                                 Disponibilité intérieure
# 3                                               Nourriture
# 4        Disponibilité alimentaire en quantité (kg/pers...
#                                ...
# 37161                                           Nourriture
# 37162    Disponibilité alimentaire en quantité (kg/pers...
# 37163       Disponibilité alimentaire (Kcal/personne/jour)
# 37164    Disponibilité de protéines en quantité (g/pers...
# 37165    Disponibilité de matière grasse en quantité (g...
# Name: Élément, Length: 37166, dtype: object

# %%
df4 = animals['Élément']
df5 = df4.values
index = pd.Index([df5])
index.columns = ['Code zone', 'Zone', 'Code Élément','Produit',
       'Élément','Valeur','Année','origine']
index.columns
# Out:
# ['Code zone',
#  'Zone',
#  'Code Élément',
#  'Produit',
#  'Élément',
#  'Valeur',
#  'Année',
#  'origine']

# %%
aniveg.drop(['Code Domaine', 'Domaine', 'Code Produit', 'Code année', 'Année', 'Unité', 'Symbole', 'Description du Symbole'],axis=1, inplace=True)
aniveg
# Out:
#         Code zone         Zone  Code Élément  \
# 0               2  Afghanistan          5511
# 1               2  Afghanistan          5611
# 2               2  Afghanistan          5301
# 3               2  Afghanistan          5142
# 4               2  Afghanistan           645
# ...           ...          ...           ...
# 104866        181     Zimbabwe           674
# 104867        181     Zimbabwe           684
# 104868        181     Zimbabwe           664
# 104869        181     Zimbabwe           674
# 104870        181     Zimbabwe           684
#
#                                                   Élément  \
# 0                                              Production
# 1                                 Importations - Quantité
# 2                                Disponibilité intérieure
# 3                                              Nourriture
# 4       Disponibilité alimentaire en quantité (kg/pers...
# ...                                                   ...
# ...

# %%
Dakg=aniveg.groupby("Élément").get_group("Disponibilité alimentaire en quantité (kg/personne/an)")
Dakg
# Out:
#         Code zone         Zone  Code Élément  \
# 4               2  Afghanistan           645
# 11              2  Afghanistan           645
# 19              2  Afghanistan           645
# 27              2  Afghanistan           645
# 34              2  Afghanistan           645
# ...           ...          ...           ...
# 104827        181     Zimbabwe           645
# 104835        181     Zimbabwe           645
# 104843        181     Zimbabwe           645
# 104852        181     Zimbabwe           645
# 104864        181     Zimbabwe           645
#
#                                                   Élément  \
# 4       Disponibilité alimentaire en quantité (kg/pers...
# 11      Disponibilité alimentaire en quantité (kg/pers...
# 19      Disponibilité alimentaire en quantité (kg/pers...
# 27      Disponibilité alimentaire en quantité (kg/pers...
# 34      Disponibilité alimentaire en quantité (kg/pers...
# ...                                                   ...
# ...

# %%
Dakcal=aniveg.groupby("Élément").get_group("Disponibilité alimentaire (Kcal/personne/jour)")
Dakcal
# Out:
#         Code zone         Zone  Code Élément  \
# 5               2  Afghanistan           664
# 12              2  Afghanistan           664
# 20              2  Afghanistan           664
# 28              2  Afghanistan           664
# 35              2  Afghanistan           664
# ...           ...          ...           ...
# 104836        181     Zimbabwe           664
# 104844        181     Zimbabwe           664
# 104853        181     Zimbabwe           664
# 104865        181     Zimbabwe           664
# 104868        181     Zimbabwe           664
#
#                                                Élément  \
# 5       Disponibilité alimentaire (Kcal/personne/jour)
# 12      Disponibilité alimentaire (Kcal/personne/jour)
# 20      Disponibilité alimentaire (Kcal/personne/jour)
# 28      Disponibilité alimentaire (Kcal/personne/jour)
# 35      Disponibilité alimentaire (Kcal/personne/jour)
# ...                                                ...
# ...

# %%
data = pd.read_csv("fr_population.csv") 
data.drop(['Code Domaine', 'Domaine', 'Code zone', 'Code Élément',
       'Élément', 'Code Produit', 'Produit', 'Code année', 'Année', 'Unité'
      , 'Symbole', 'Description du Symbole'],axis=1, inplace=True)
data['Valpop'] = data ['Valeur']*1000
data.head(20)
data.columns
# Out:
# Index(['Zone', 'Valeur', 'Valpop'], dtype='object')

# %%
pop = aniveg.merge(data)
pop.head()
# Out:
# c:\users\philippe\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\reshape\merge.py:1084: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation
#   warnings.warn(
#    Code zone       Zone  Code Élément  \
# 0         55  Dominique           664
#
#                                           Élément             Produit  Valeur  \
# 0  Disponibilité alimentaire (Kcal/personne/jour)  Coco (Incl Coprah)    72.0
#
#    origine  Valpop
# 0  vegetal   72000

# %%
pop
# Out:
#    Code zone       Zone  Code Élément  \
# 0         55  Dominique           664
#
#                                           Élément             Produit  Valeur  \
# 0  Disponibilité alimentaire (Kcal/personne/jour)  Coco (Incl Coprah)    72.0
#
#    origine  Valpop
# 0  vegetal   72000

# %%
table = pd.pivot_table(aniveg, values='Valeur', index=['Élément'],
                    columns=['Zone'])
table
# Out:
# Zone                                                Afghanistan  \
# Élément
# Aliments pour animaux                                128.000000
# Autres utilisations (non alimentaire)                103.750000
# Disponibilité alimentaire (Kcal/personne/jour)        37.945455
# Disponibilité alimentaire en quantité (kg/perso...     6.507593
# Disponibilité de matière grasse en quantité (g/...     0.728261
# Disponibilité de protéines en quantité (g/perso...     1.387143
# Disponibilité intérieure                             229.067797
# Exportations - Quantité                               14.631579
# Importations - Quantité                               66.400000
# Nourriture                                           198.796296
# Pertes                                                63.055556
# Production                                           286.435897
# Semences                                              32.916667
# ...

# %%
table2 = pd.pivot_table(aniveg, values='Valeur', index=['Produit','Zone'],
                    columns=['Élément'],aggfunc=np.sum)
table2
# Out:
# Élément                                 Aliments pour animaux  \
# Produit          Zone
# Abats Comestible Afghanistan                              NaN
#                  Afrique du Sud                           0.0
#                  Albanie                                  NaN
#                  Algérie                                  NaN
#                  Allemagne                                1.0
# ...                                                       ...
# Épices, Autres   Émirats arabes unis                      NaN
#                  Équateur                                 NaN
#                  États-Unis d'Amérique                    NaN
#                  Éthiopie                                 NaN
#                  Îles Salomon                             NaN
#
# Élément                                 Autres utilisations (non alimentaire)  \
# Produit          Zone
# Abats Comestible Afghanistan                                              NaN
# ...

# %%
table3 = pd.pivot_table(aniveg, values='Valeur', index=['Zone','Élément'],
                    columns=['Produit'])
table3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-5cb4931aa76a> in <module>
# ----> 1 table3 = pd.pivot_table(aniveg, values='Valeur', index=['Zone','Élément'],
#       2                     columns=['Produit'])
#       3 table3
#
# NameError: name 'pd' is not defined

# %%
table4 = pd.pivot_table(aniveg, values='Valeur', index=['Élément','Produit'],
                    columns=['Zone'],aggfunc=np.sum)
table4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a60a94b2c59c> in <module>
# ----> 1 table4 = pd.pivot_table(aniveg, values='Valeur', index=['Élément','Produit'],
#       2                     columns=['Zone'],aggfunc=np.sum)
#       3 table4
#
# NameError: name 'pd' is not defined

# %%
table2 = pd.pivot_table(aniveg, values='Valeur', index=['Produit','Zone'],
                    columns=['Élément'],aggfunc=np.sum)
table2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-6f5f69821358> in <module>
# ----> 1 table2 = pd.pivot_table(aniveg, values='Valeur', index=['Produit','Zone'],
#       2                     columns=['Élément'],aggfunc=np.sum)
#       3 table2
#
# NameError: name 'pd' is not defined
